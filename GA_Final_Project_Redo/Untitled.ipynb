# %% [markdown]
# # Second Attempt on DF data clean

# %%
import pandas as pd
import numpy as np
import json

# %%
df = pd.read_csv("Final_Project_data_v2.csv", engine='c')
print (df.head(10))
# Out:
#   portal_id                csid    close_date churn_recognized_date  \
# 0    454960  a0E7000000KBUxzEAH  5/15/15 0:00                   NaN
# 1    533390  a0E7000000KBelnEAD  5/20/15 0:00                   NaN
# 2    539692  a0E7000000KBRbSEAX  5/12/15 0:00         11/13/15 0:00
# 3    522790  a0E7000000KBjreEAD  5/29/15 0:00          3/15/16 0:00
# 4    538122  a0E7000000KBW8xEAH  5/18/15 0:00          5/17/16 0:00
# 5    531632  a0E7000000KBfseEAD  5/22/15 0:00          6/21/16 0:00
# 6    541310  a0E7000000KBjItEAL  5/28/15 0:00                   NaN
# 7    536879  a0E7000000KBSIwEAP  5/13/15 0:00          6/13/16 0:00
# 8    537593  a0E7000000KBkfeEAD  5/29/15 0:00                   NaN
# 9    554681  a0E7000000KBkb8EAD  5/29/15 0:00                   NaN
#
#    churn_flag          am_owner_name  day_30_distinct_app_m  \
# 0           0             Alan Lynam                   14.0
# 1           0             Maria Diez                    5.0
# ...

# %%
df.columns
# Out:
# Index(['portal_id', 'csid', 'close_date', 'churn_recognized_date',
#        'churn_flag', 'am_owner_name', 'day_30_distinct_app_m',
#        'day_30_total_app_usage_m', 'day_30_users_m', 'day_60_distinct_app_m',
#        'day_60_total_app_usage_m', 'day_60_users_m', 'day_90_distinct_app_m',
#        'day_90_total_app_usage_m', 'day_90_users_m', 'day_30_distinct_app_s',
#        'day_30_total_app_usage_s', 'day_30_users_s', 'day_60_distinct_app_s',
#        'day_60_total_app_usage_s', 'day_60_users_s', 'day_90_distinct_app_s',
#        'day_90_total_app_usage_s', 'day_90_users_s', 'day_0_mrr', 'day_0_date',
#        'day_180_mrr', 'day_180_date', 'day_0_product_list',
#        'day_0_distinct_product', 'day_180_list', 'day_180_distinct_product'],
#       dtype='object')

# %%
col_to_keep = ['portal_id', 'csid', 'close_date', 'churn_recognized_date',
       'churn_flag', 'am_owner_name', 'day_30_distinct_app_m',
       'day_30_total_app_usage_m', 'day_30_users_m']
df_small = df[col_to_keep]
df_small.head(5)
# Out:
#   portal_id                csid    close_date churn_recognized_date  \
# 0    454960  a0E7000000KBUxzEAH  5/15/15 0:00                   NaN
# 1    533390  a0E7000000KBelnEAD  5/20/15 0:00                   NaN
# 2    539692  a0E7000000KBRbSEAX  5/12/15 0:00         11/13/15 0:00
# 3    522790  a0E7000000KBjreEAD  5/29/15 0:00          3/15/16 0:00
# 4    538122  a0E7000000KBW8xEAH  5/18/15 0:00          5/17/16 0:00
#
#    churn_flag          am_owner_name  day_30_distinct_app_m  \
# 0           0             Alan Lynam                   14.0
# 1           0             Maria Diez                    5.0
# 2           1            Amelia Hall                    3.0
# 3           1       Varun Bhandarkar                   17.0
# 4           1  Customer Success Team                   21.0
#
#    day_30_total_app_usage_m  day_30_users_m
# 0                     536.0             3.0
# 1                     383.0             7.0
# 2                      43.0             3.0
# ...

# %%
df_small.drop('csid', axis = 1, inplace = True)
df_small.head(5)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#   portal_id    close_date churn_recognized_date  churn_flag  \
# 0    454960  5/15/15 0:00                   NaN           0
# 1    533390  5/20/15 0:00                   NaN           0
# 2    539692  5/12/15 0:00         11/13/15 0:00           1
# 3    522790  5/29/15 0:00          3/15/16 0:00           1
# 4    538122  5/18/15 0:00          5/17/16 0:00           1
#
#            am_owner_name  day_30_distinct_app_m  day_30_total_app_usage_m  \
# 0             Alan Lynam                   14.0                     536.0
# 1             Maria Diez                    5.0                     383.0
# ...

# %%
df_small.iloc[1,1]
# Out:
# '5/20/15 0:00'

# %%
df_small.iloc[:3, -3:]
# Out:
#    day_30_distinct_app_m  day_30_total_app_usage_m  day_30_users_m
# 0                   14.0                     536.0             3.0
# 1                    5.0                     383.0             7.0
# 2                    3.0                      43.0             3.0

# %%
df_small['am_owner_name'][:5] = ['Alan', 'Alan', 'Mariz', 'Maria', 'Varun' ]
df_small.head(5)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/pandas/core/series.py:767: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._set_with(key, value)
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/IPython/core/interactiveshell.py:2862: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
df_small['day_30_total_app_usage_m'].head(5).groupby(df_small['am_owner_name']).mean()
# Out:
# am_owner_name
# Alan      459.5
# Maria    1638.0
# Mariz      43.0
# Varun     729.0
# Name: day_30_total_app_usage_m, dtype: float64

# %%
pd.concat([df_small.head(5), df_small.head(5)])
# Out:
#   portal_id    close_date churn_recognized_date  churn_flag am_owner_name  \
# 0    454960  5/15/15 0:00                   NaN           0          Alan
# 1    533390  5/20/15 0:00                   NaN           0          Alan
# 2    539692  5/12/15 0:00         11/13/15 0:00           1         Mariz
# 3    522790  5/29/15 0:00          3/15/16 0:00           1         Maria
# 4    538122  5/18/15 0:00          5/17/16 0:00           1         Varun
# 0    454960  5/15/15 0:00                   NaN           0          Alan
# 1    533390  5/20/15 0:00                   NaN           0          Alan
# 2    539692  5/12/15 0:00         11/13/15 0:00           1         Mariz
# 3    522790  5/29/15 0:00          3/15/16 0:00           1         Maria
# 4    538122  5/18/15 0:00          5/17/16 0:00           1         Varun
#
#    day_30_distinct_app_m  day_30_total_app_usage_m  day_30_users_m
# 0                   14.0                     536.0             3.0
# ...
