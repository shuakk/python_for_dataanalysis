# %% [markdown]
# # Read in File, Data Loading

# %%
folder_dir = '/Users/KK/Documents/python_for_dataanalysis/Chapter_6'
file_name = 'read_in_txt.txt'

#f = open(folder_dir + file_name, 'r')
f = open(file_name, 'r')
print(f)
# Out:
# <_io.TextIOWrapper name='read_in_txt.txt' mode='r' encoding='UTF-8'>

# %%
list(open(file_name, 'r'))
# Out:
# ['hello world\n', 'this is su\n', 'this is the third line of the file\n']

# %%
f = open(file_name, 'r')
print(f.read())
# Out:
# hello world
# this is su
# this is the third line of the file

# %%
f = open(file_name, 'r')
f.readline()
# Out:
# 'hello world\n'

# %%
print(f.read())

# %%
f = open(file_name, 'r')
for line in f:
    print(line)
# Out:
# hello world
#
# this is su
#
# this is the third line of the file

# %%
with open(file_name, 'r') as f:
    print(f.readline())
# Out:
# hello world

# %%
with open(file_name, 'r') as f:
    print(f.readlines())
# Out:
# ['hello world\n', 'this is su\n', 'this is the third line of the file\n']

# %%
with open(file_name, 'r') as f:
    line = f.readlines()
    print(line)
# Out:
# ['hello world\n', 'this is su\n', 'this is the third line of the file\n']

# %%
with open(file_name, 'r') as f:
    for line in f:
        print(line)
# Out:
# hello world
#
# this is su
#
# this is the third line of the file

# %%
data_dir = 'cohort_challenge.csv'
import pandas as pd

df = pd.read_csv(data_dir, sep = ',')
df.head(5)
# Out:
#      Date          Game     Network Country OS Name  Days after Install  \
# 0  7/1/16  Awesome Game  Network 1s      us     iOS                   0
# 1  7/1/16  Awesome Game  Network 1s      us     iOS                   0
# 2  7/1/16  Awesome Game  Network 1s      us     iOS                   0
# 3  7/1/16  Awesome Game  Network 1s      us     iOS                   0
# 4  7/1/16  Awesome Game  Network 1s      us     iOS                   0
#
#    Users  Cohort Size  FTD  Revenue
# 0   21.0         21.0  NaN      NaN
# 1    2.0          2.0  NaN      NaN
# 2    2.0          2.0  NaN      NaN
# 3    1.0          1.0  NaN      NaN
# 4    1.0          1.0  NaN      NaN

# %%
data_dir2 = 'cohort_challenge_no_header.csv'
df2 = pd.read_csv(data_dir2, sep = ',', names = ['mDate',
 'mGame',
 'mNetwork',
 'mCountry',
 'mOS Name',
 'mDays after Install',
 'mUsers',
 'Cohort Size',
 'mFTD',
 'mRevenue'])
df2.head(5)
# Out:
#     mDate         mGame    mNetwork mCountry mOS Name  mDays after Install  \
# 0  7/1/16  Awesome Game  Network 1s       us      iOS                    0
# 1  7/1/16  Awesome Game  Network 1s       us      iOS                    0
# 2  7/1/16  Awesome Game  Network 1s       us      iOS                    0
# 3  7/1/16  Awesome Game  Network 1s       us      iOS                    0
# 4  7/1/16  Awesome Game  Network 1s       us      iOS                    0
#
#    mUsers  Cohort Size  mFTD  mRevenue
# 0      21           21   NaN       NaN
# 1       2            2   NaN       NaN
# 2       2            2   NaN       NaN
# 3       1            1   NaN       NaN
# 4       1            1   NaN       NaN

# %%
df2.head(5)
# Out:
#     mDate         mGame    mNetwork mCountry mOS Name  mDays after Install  \
# 0  7/1/16  Awesome Game  Network 1s       us      iOS                    0
# 1  7/1/16  Awesome Game  Network 1s       us      iOS                    0
# 2  7/1/16  Awesome Game  Network 1s       us      iOS                    0
# 3  7/1/16  Awesome Game  Network 1s       us      iOS                    0
# 4  7/1/16  Awesome Game  Network 1s       us      iOS                    0
#
#    mUsers  Cohort Size  mFTD  mRevenue
# 0      21           21   NaN       NaN
# 1       2            2   NaN       NaN
# 2       2            2   NaN       NaN
# 3       1            1   NaN       NaN
# 4       1            1   NaN       NaN

# %%
pd.isnull(df2.head(5))
# Out:
#    mDate  mGame  mNetwork  mCountry  mOS Name  mDays after Install  mUsers  \
# 0  False  False     False     False     False                False   False
# 1  False  False     False     False     False                False   False
# 2  False  False     False     False     False                False   False
# 3  False  False     False     False     False                False   False
# 4  False  False     False     False     False                False   False
#
#    Cohort Size  mFTD  mRevenue
# 0        False  True      True
# 1        False  True      True
# 2        False  True      True
# 3        False  True      True
# 4        False  True      True

# %% [markdown]
# ## My own proactice based on read and df manipulation from previous chapter

# %%
df.head(5)
# Out:
#      Date          Game     Network Country OS Name  Days after Install  \
# 0  7/1/16  Awesome Game  Network 1s      us     iOS                   0
# 1  7/1/16  Awesome Game  Network 1s      us     iOS                   0
# 2  7/1/16  Awesome Game  Network 1s      us     iOS                   0
# 3  7/1/16  Awesome Game  Network 1s      us     iOS                   0
# 4  7/1/16  Awesome Game  Network 1s      us     iOS                   0
#
#    Users  Cohort Size  FTD  Revenue
# 0   21.0         21.0  NaN      NaN
# 1    2.0          2.0  NaN      NaN
# 2    2.0          2.0  NaN      NaN
# 3    1.0          1.0  NaN      NaN
# 4    1.0          1.0  NaN      NaN

# %%
#Retrieve cohort size = 21, Data = 7/1/16, network = network 1s
df_special_cohort = df[(df['Date'] == '7/1/16') & (df['Network'] == 'Network 1s') & (df['Cohort Size']==21)]

# %%
df_special_cohort
# Out:
#           Date          Game     Network Country OS Name  Days after Install  \
# 0       7/1/16  Awesome Game  Network 1s      us     iOS                   0
# 25035   7/1/16  Awesome Game  Network 1s      us     iOS                   1
# 50012   7/1/16  Awesome Game  Network 1s      us     iOS                   2
# 74988   7/1/16  Awesome Game  Network 1s      us     iOS                   3
# 99964   7/1/16  Awesome Game  Network 1s      us     iOS                   4
# 124941  7/1/16  Awesome Game  Network 1s      us     iOS                   5
# 149917  7/1/16  Awesome Game  Network 1s      us     iOS                   6
# 174893  7/1/16  Awesome Game  Network 1s      us     iOS                   7
# 199869  7/1/16  Awesome Game  Network 1s      us     iOS                   8
# 224845  7/1/16  Awesome Game  Network 1s      us     iOS                   9
# 249821  7/1/16  Awesome Game  Network 1s      us     iOS                  10
# ...

# %%
df_special_cohort.index = range(len(df_special_cohort.index))

# %%
df_special_cohort.head(10)
# Out:
#      Date          Game     Network Country OS Name  Days after Install  \
# 0  7/1/16  Awesome Game  Network 1s      us     iOS                   0
# 1  7/1/16  Awesome Game  Network 1s      us     iOS                   1
# 2  7/1/16  Awesome Game  Network 1s      us     iOS                   2
# 3  7/1/16  Awesome Game  Network 1s      us     iOS                   3
# 4  7/1/16  Awesome Game  Network 1s      us     iOS                   4
# 5  7/1/16  Awesome Game  Network 1s      us     iOS                   5
# 6  7/1/16  Awesome Game  Network 1s      us     iOS                   6
# 7  7/1/16  Awesome Game  Network 1s      us     iOS                   7
# 8  7/1/16  Awesome Game  Network 1s      us     iOS                   8
# 9  7/1/16  Awesome Game  Network 1s      us     iOS                   9
#
#    Users  Cohort Size  FTD  Revenue
# 0   21.0         21.0  NaN      NaN
# 1    9.0         21.0  NaN      NaN
# 2    7.0         21.0  NaN      NaN
# ...

# %%
df_special_cohort.index.name = 'Dummy index name'
df_special_cohort.index.name
# Out:
# 'Dummy index name'

# %%
df_special_cohort.columns.name = 'Dummy column name'
df_special_cohort.columns.name
# Out:
# 'Dummy column name'

# %%
df_special_cohort.head(10)
# Out:
# Dummy column name    Date          Game     Network Country OS Name  \
# Dummy index name
# 0                  7/1/16  Awesome Game  Network 1s      us     iOS
# 1                  7/1/16  Awesome Game  Network 1s      us     iOS
# 2                  7/1/16  Awesome Game  Network 1s      us     iOS
# 3                  7/1/16  Awesome Game  Network 1s      us     iOS
# 4                  7/1/16  Awesome Game  Network 1s      us     iOS
# 5                  7/1/16  Awesome Game  Network 1s      us     iOS
# 6                  7/1/16  Awesome Game  Network 1s      us     iOS
# 7                  7/1/16  Awesome Game  Network 1s      us     iOS
# 8                  7/1/16  Awesome Game  Network 1s      us     iOS
# 9                  7/1/16  Awesome Game  Network 1s      us     iOS
#
# Dummy column name  Days after Install  Users  Cohort Size  FTD  Revenue
# Dummy index name
# 0                                   0   21.0         21.0  NaN      NaN
# ...

# %%
#pick a subset of data
df_special_cohort.iloc[0:5, [0,2,5,6]]
# Out:
# Dummy column name    Date     Network  Days after Install  Users
# Dummy index name
# 0                  7/1/16  Network 1s                   0   21.0
# 1                  7/1/16  Network 1s                   1    9.0
# 2                  7/1/16  Network 1s                   2    7.0
# 3                  7/1/16  Network 1s                   3    5.0
# 4                  7/1/16  Network 1s                   4    6.0

# %%
df_special_cohort.iloc[0:5, 1:]
# Out:
# Dummy column name          Game     Network Country OS Name  \
# Dummy index name
# 0                  Awesome Game  Network 1s      us     iOS
# 1                  Awesome Game  Network 1s      us     iOS
# 2                  Awesome Game  Network 1s      us     iOS
# 3                  Awesome Game  Network 1s      us     iOS
# 4                  Awesome Game  Network 1s      us     iOS
#
# Dummy column name  Days after Install  Users  Cohort Size  FTD  Revenue
# Dummy index name
# 0                                   0   21.0         21.0  NaN      NaN
# 1                                   1    9.0         21.0  NaN      NaN
# 2                                   2    7.0         21.0  NaN      NaN
# 3                                   3    5.0         21.0  NaN      NaN
# 4                                   4    6.0         21.0  NaN      NaN

# %%
del df_special_cohort.index.name
del df_special_cohort.columns.name
df_special_cohort
# Out:
#       Date          Game     Network Country OS Name  Days after Install  \
# 0   7/1/16  Awesome Game  Network 1s      us     iOS                   0
# 1   7/1/16  Awesome Game  Network 1s      us     iOS                   1
# 2   7/1/16  Awesome Game  Network 1s      us     iOS                   2
# 3   7/1/16  Awesome Game  Network 1s      us     iOS                   3
# 4   7/1/16  Awesome Game  Network 1s      us     iOS                   4
# 5   7/1/16  Awesome Game  Network 1s      us     iOS                   5
# 6   7/1/16  Awesome Game  Network 1s      us     iOS                   6
# 7   7/1/16  Awesome Game  Network 1s      us     iOS                   7
# 8   7/1/16  Awesome Game  Network 1s      us     iOS                   8
# 9   7/1/16  Awesome Game  Network 1s      us     iOS                   9
# 10  7/1/16  Awesome Game  Network 1s      us     iOS                  10
# 11  7/1/16  Awesome Game  Network 1s      us     iOS                  11
# ...
